# %%
import torch.nn.functional as F
# %load_ext autoreload
# %autoreload 2

# %%
from dvrl.training.train import run_dvrl

# %%
prediction_hparams = {'pred_hidden_dim': 256,
                      'pred_num_layers': 5,
                      'activation_fn': F.relu,
                      'predictor_lr': 1e-3,
                      'num_classes': 10,
                      'inner_batch_size': 32,
                      'num_inner_iterations': 100
                      }

# %%
dvrl_hparams = {'dve_hidden_dim': 256,
                'dve_comb_dim': 128,
                'dve_num_layers': 5,
                'dve_lr': 1e-2,
                'epsilon': 1e-8,
                'T': 20,
                'num_classes':10,
                'outer_batch_size':2000
                }

# %%
run_dvrl(prediction_hparams=prediction_hparams, dvrl_hparams=dvrl_hparams)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/raw/cifar/cifar-10-python.tar.gz
# Extracting data/raw/cifar/cifar-10-python.tar.gz to data/raw/cifar
# Files already downloaded and verified
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /home/saurabh/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# /home/saurabh/miniconda3/envs/dvrl/lib/python3.7/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729047590/work/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# ---------------------------------------------------------------------------
# MisconfigurationException                 Traceback (most recent call last)
# <ipython-input-6-71344898e198> in <module>
#       1 # pydev_debug_cell
# ----> 2 run_dvrl(prediction_hparams=prediction_hparams, dvrl_hparams=dvrl_hparams)
#
# ~/Documents/Reinforcement learning/rl_project/dvrl/dvrl/training/train.py in run_dvrl(prediction_hparams, dvrl_hparams)
#      17     pred_model = DVRLPredictionModel(prediction_hparams)
#      18     dvrl_model = DVRL(dvrl_hparams, pred_model, val_dataloader, datamodule.val_split)
# ---> 19     trainer = Trainer(gpus=1)
#      20     trainer.fit(dvrl_model, train_dataloader=train_dataloader, val_dataloaders=test_dataloader)
#      21
#
# ~/miniconda3/envs/dvrl/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/env_vars_connector.py in overwrite_by_env_vars(self, *args, **kwargs)
#      39
#      40         # all args were already moved to kwargs
# ---> 41         return fn(self, **kwargs)
#      42
#      43     return overwrite_by_env_vars
#
# ~/miniconda3/envs/dvrl/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in __init__(self, logger, checkpoint_callback, callbacks, default_root_dir, gradient_clip_val, process_position, num_nodes, num_processes, gpus, auto_select_gpus, tpu_cores, log_gpu_memory, progress_bar_refresh_rate, overfit_batches, track_grad_norm, check_val_every_n_epoch, fast_dev_run, accumulate_grad_batches, max_epochs, min_epochs, max_steps, min_steps, limit_train_batches, limit_val_batches, limit_test_batches, val_check_interval, flush_logs_every_n_steps, log_every_n_steps, accelerator, sync_batchnorm, precision, weights_summary, weights_save_path, num_sanity_val_steps, truncated_bptt_steps, resume_from_checkpoint, profiler, benchmark, deterministic, reload_dataloaders_every_epoch, auto_lr_find, replace_sampler_ddp, terminate_on_nan, auto_scale_batch_size, prepare_data_per_node, plugins, amp_backend, amp_level, distributed_backend, automatic_optimization)
#     344             benchmark,
#     345             replace_sampler_ddp,
# --> 346             deterministic,
#     347         )
#     348
#
# ~/miniconda3/envs/dvrl/lib/python3.7/site-packages/pytorch_lightning/accelerators/accelerator_connector.py in on_trainer_init(self, num_processes, tpu_cores, accelerator, distributed_backend, auto_select_gpus, gpus, num_nodes, log_gpu_memory, sync_batchnorm, benchmark, replace_sampler_ddp, deterministic)
#     109             self.trainer.gpus = self.trainer.tuner.pick_multiple_gpus(gpus)
#     110
# --> 111         self.trainer.data_parallel_device_ids = device_parser.parse_gpu_ids(self.trainer.gpus)
#     112         self.trainer.root_gpu = device_parser.determine_root_gpu_device(self.trainer.data_parallel_device_ids)
#     113         self.trainer.root_device = torch.device("cpu")
#
# ~/miniconda3/envs/dvrl/lib/python3.7/site-packages/pytorch_lightning/utilities/device_parser.py in parse_gpu_ids(gpus)
#      74     if not gpus:
#      75         raise MisconfigurationException("GPUs requested but none are available.")
# ---> 76     gpus = _sanitize_gpu_ids(gpus)
#      77
#      78     return gpus
#
# ~/miniconda3/envs/dvrl/lib/python3.7/site-packages/pytorch_lightning/utilities/device_parser.py in _sanitize_gpu_ids(gpus)
#     135                 You requested GPUs: {gpus}
#     136                 But your machine only has: {all_available_gpus}
# --> 137             """)
#     138     return gpus
#     139
#
# MisconfigurationException:
#                 You requested GPUs: [0]
#                 But your machine only has: []
